# %% [markdown]
# # Python-Syntax-Task

# %% [markdown]
# Hey everyone!!
#
# It's time to put what you've learnt to the test!!
#
# Solve the following few tasks using the skills that you've developed from yesterday
#
# Feel free to refer back to the previous notebooks in case you feel like youre forgetting something

# %% [markdown]
# ## Task 1

# %% [markdown]
# This task is related to lists, dictionaries and functions
#
# Read the instructions given in the comments and write the code accordingly

# %%
task_list = [23,45,21,34,56,75,33,45,90,21,34,67]
# Don't forget to run this cell

# %%
# In this cell define a function to which you pass the task_list and print all the values that are greater than 50
def '''Enter code below'''




'''After making that function, call it'''
<insert function name>(task_list)
# for example, sub_task1(task_list)

# %%
# In this cell, make a function to print the 2nd,3rd,4th, 6th,7th,8th and 10th,11th,12th elements of task_list
# Remember to use the ':' operator

def '''Enter code below'''


#Similar to the previous one call the function below

# %%
'''Your next subtask is to insert the element 45 at the 3rd position in the list and remove 67 from the list'''
# Again make functions and call them

# %%
'''Find all the unique elements of the array using numpy!!! 
45, 21 and 34 should not come more than once here!!!'''

# %% [markdown]
# #### You're almost there! Only one sub task left!!

# %%
task_dict = {'a':'apple','b':'bulb','c':'cat'}
#Don't forget to run this cell

# %%
'''Replace the value of the key b to ball
After this add a new element with key d and value dog'''
# Write your code in this cell right here!!

# %% [markdown]
# ### Congratulations!! You've made it through the first task!!

# %% [markdown]
# ## Task 2

# %% [markdown]
# It's time to gear up for a slightly harder task!!
#
# Get ready to become a Python Professional!!

# %% [markdown]
# All you have to do is finish these sub-tasks and make the class completely functional

# %%
class #define a class with the name 'student' here
    def '''Initialise the class with 3 parameters - Name and Age(What is the 3rd parameter?)'''
        
    def get_scores(self,score1, score2, score3): # Entering the scores of the student in three subjects
        self.score1 = score1
        self.score2 = score2
        self.score3 = score3
    
    def get_grade(self):
        ''' Make a function to return the grade the student has received in the three subjects
        The grading system is as follows:
        score > 85 => Grade = A
        85 >= score > 70 => Grade = B
        70 >= score >=55 => Grade = C
        score<55 => Grade = D
        print the grades of the students in the three subjects along with their Name and Age'''
    
student_list = [['Adam', 16, 84, 70, 31],
               ['Andrew', 17, 99, 92, 64],
               ['Ian', 16, 85, 70, 55]]
#Every Item of the list represents ['Name', Age, Score1, Score2, Score3]

#Use a for-loop to go through the list and create an object for each student

for i in range(len(student_list)):
    #Enter code here

# %% [markdown]
# Woahh!!
#
# You managed to finish that hard a task!!
# Congratulations!!
#
# You can now confidently say that your python skills are at a good level!!
#
# All the best and see you all in the next notebook!!
